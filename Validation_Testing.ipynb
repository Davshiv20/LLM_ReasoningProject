# %%
import os
import json
import boto3
from botocore.exceptions import ClientError
import re
from dotenv import load_dotenv
from typing import List, Dict

load_dotenv()

class MathReasoningLLM:
    def __init__(self):
        self.region_name = os.getenv('AWS_REGION')
        self.model_id = os.getenv('BEDROCK_MODEL_ID')
        self.aws_access_key_id = os.getenv('AWS_ACCESS_KEY_ID')
        self.aws_secret_access_key = os.getenv('AWS_SECRET_ACCESS_KEY')
        
        if not all([self.region_name, self.model_id, self.aws_access_key_id, self.aws_secret_access_key]):
            raise ValueError("Missing required environment variables. Please check your .env file.")
        
        self.client = boto3.client('bedrock-runtime', 
                                   region_name=self.region_name,
                                   aws_access_key_id=self.aws_access_key_id,
                                   aws_secret_access_key=self.aws_secret_access_key)
        self.dataset = self.load_dataset()[:5]  # Load only first 5 questions

    def load_dataset(self) -> List[Dict]:
        with open('RepresentativeDataset.json', 'r') as f:
            return json.load(f)

    def create_prompt(self, question: str, options: List[str]) -> str:
        prompt = f"Solve the following mathematical problem:\n\nQuestion: {question}\n"
        prompt += f"Options: {', '.join(options)}\n\n"
        prompt += "Provide your solution step by step and clearly state your final answer at the end, prefixed with the option letter as 'Final Answer: '."
        return f"""<begin_of_text>
<start_header_id>user<end_header_id>
{prompt}
<eot_id>
<start_header_id>assistant<end_header_id>
"""

    def create_grading_prompt(self, problem: Dict, solution: str) -> str:
        prompt = f"""Evaluate the following solution to this math problem:

Problem: {problem['question']}
Correct Answer: {problem['answer']}

Given Solution:
{solution}

Please provide:
1. A score from 0 to 1, where 0 is completely incorrect and 1 is perfectly correct.
2. A brief explanation of the score.
3. State whether the final answer matches the correct answer (Yes/No).

Format your response as:
Score: [score]
Explanation: [your explanation]
Correct Final Answer: [Yes/No]
"""
        return f"""<begin_of_text>
<start_header_id>user<end_header_id>
{prompt}
<eot_id>
<start_header_id>assistant<end_header_id>
"""

    def invoke_model(self, prompt: str, max_tokens: int = 1024, temperature: float = 0.7) -> str:
        request_body = {
            "prompt": prompt,
            "max_gen_len": max_tokens,
            "temperature": temperature,
        }
        
        try:
            response = self.client.invoke_model(
                body=json.dumps(request_body),
                contentType='application/json',
                modelId=self.model_id
            )
            response_body = json.loads(response['body'].read().decode('utf-8'))
            return response_body.get('generation', '')
        except ClientError as e:
            print(f"ERROR: Can't invoke '{self.model_id}'. Reason: {e}")
            return None

    def extract_model_answer(self, model_solution: str) -> str:
        match = re.search(r"Final Answer:\s*(\w+)", model_solution, re.IGNORECASE)
        if match:
            return match.group(1).lower()
        return None

    def generate_solution_paths(self, problem: Dict, max_paths: int = 5) -> List[str]:
        paths = []
        for _ in range(max_paths):
            response = self.invoke_model(self.create_prompt(problem['question'], problem['options']))
            if response and response not in paths:
                paths.append(response)
            if len(paths) == max_paths or _ == max_paths - 1:
                break
        return paths

    def grade_solution_path(self, problem: Dict, solution: str) -> Dict:
        response = self.invoke_model(self.create_grading_prompt(problem, solution))
        
        score_match = re.search(r"Score:\s*(\d+(\.\d+)?)", response)
        explanation_match = re.search(r"Explanation:\s*(.+?)(?:\n|$)", response, re.DOTALL)
        correct_answer_match = re.search(r"Correct Final Answer:\s*(Yes|No)", response)
        
        score = float(score_match.group(1)) if score_match else 0.0
        explanation = explanation_match.group(1) if explanation_match else "No explanation provided"
        correct_final_answer = correct_answer_match.group(1) == "Yes" if correct_answer_match else False
        
        return {
            "score": score,
            "explanation": explanation,
            "correct_final_answer": correct_final_answer
        }

    def validate_answer(self, problem: Dict, model_answer: str) -> bool:
        correct_answer = problem['answer'].lower()
        
        if model_answer and len(model_answer) == 1 and model_answer.isalpha():
            return model_answer.lower() == correct_answer
        
        if correct_answer.isalpha() and ord('a') <= ord(correct_answer) <= ord('d'):
            index = ord(correct_answer) - ord('a')
            if 0 <= index < len(problem['options']):
                correct_option = problem['options'][index]
                return self.compare_latex(model_answer, correct_option)
        
        return False

    def compare_latex(self, expr1: str, expr2: str) -> bool:
        clean1 = re.sub(r'[\\{\}\s]', '', expr1)
        clean2 = re.sub(r'[\\{\}\s]', '', expr2)
        return clean1 == clean2

    def solve_problem(self, problem: Dict) -> Dict:
        paths = self.generate_solution_paths(problem)
        graded_paths = []
        for path in paths:
            model_answer = self.extract_model_answer(path)
            grade_result = self.grade_solution_path(problem, path)
            is_correct = self.validate_answer(problem, model_answer) if model_answer else False
            
            if grade_result['correct_final_answer'] and is_correct:
                graded_paths.append({
                    "solution": path,
                    "grade": grade_result['score'],
                    "explanation": grade_result['explanation'],
                    "model_answer": model_answer,
                    "is_correct": is_correct
                })
        
        graded_paths.sort(key=lambda x: x["grade"], reverse=True)
        return {
            "question": problem['question'],
            "options": problem['options'],
            "correct_answer": problem['answer'],
            "solutions": graded_paths
        }

    def improve_reasoning(self) -> List[Dict]:
        results = []
        for problem in self.dataset:
            result = self.solve_problem(problem)
            results.append(result)
        return results

def main():
    try:
        llm = MathReasoningLLM()
        results = llm.improve_reasoning()

        print("Results:")
        total_correct = 0
        for i, result in enumerate(results, 1):
            print(f"\nProblem {i}:")
            print(f"Q: {result['question']}")
            print(f"Options: {', '.join(result['options'])}")
            print(f"Correct answer: {result['correct_answer']}")
            for j, solution in enumerate(result['solutions'], 1):
                print(f"\nSolution {j} (Grade: {solution['grade']:.2f}):")
                print(f"Model's solution:\n{solution['solution']}")
                print(f"Model's extracted answer: {solution['model_answer']}")
                print(f"Is correct: {solution['is_correct']}")
                print(f"Explanation: {solution['explanation']}")
            
            correct_solutions = len(result['solutions'])
            total_correct += 1 if correct_solutions > 0 else 0
            print(f"Number of correct solutions: {correct_solutions}")
            print("-" * 50)

        accuracy = total_correct / len(results) if results else 0
        print(f"\nOverall Accuracy: {accuracy:.2%}")

    except ValueError as e:
        print(f"Error: {e}")
        print("Please ensure all required environment variables are set in your .env file:")
        print("AWS_REGION, BEDROCK_MODEL_ID, AWS_ACCESS_KEY_ID, AWS_SECRET_ACCESS_KEY")

if __name__ == "__main__":
    main()
# Out:
# Results:
#
# Problem 1:
# Q: If \(\int\left(e^{2 x}+2 e^{x}-e^{-x}-1\right) e^{\left(e^{x}+e^{-x}\right)} d x=g(x) e^{\left(e^{x}+e^{-x}\right)}+c\), where \(c\) is a constant of integeration, then \(g(0)\) is equal to:
# Options: \(e\), \(e^{2}\), 1, 2
# Correct answer: d
#
# Solution 1 (Grade: 0.80):
# Model's solution:
# To solve this problem, we can start by noticing that the given integral is a product of two functions:
#
# $$\int\left(e^{2 x}+2 e^{x}-e^{-x}-1\right) e^{\left(e^{x}+e^{-x}\right)} d x$$
#
# Let's call the first function $f(x) = e^{2 x}+2 e^{x}-e^{-x}-1$ and the second function $h(x) = e^{\left(e^{x}+e^{-x}\right)}$.
#
# We can then use the substitution method to evaluate the integral. Let's substitute $u = e^{x} + e^{-x}$, which implies that $du/dx = e^{x} - e^{-x}$. Then, we have:
#
# $$dx = \frac{du}{e^{x} - e^{-x}}$$
#
# Now, we can rewrite the integral as:
#
# $$\int\left(e^{2 x}+2 e^{x}-e^{-x}-1\right) e^{\left(e^{x}+e^{-x}\right)} d x = \int\left(u^{2}+2 u-u^{-1}-1\right) e^{u} \frac{du}{e^{x} - e^{-x}}$$
#
# Simplifying the integral, we get:
#
# $$\int\left(u^{2}+2 u-u^{-1}-1\right) e^{u} \frac{du}{e^{x} - e^{-x}} = \int\left(u^{2}+2 u-u^{-1}-1\right) e^{u} \frac{du}{u - u^{-1}}$$
#
# Now, we can integrate by parts:
#
# $$\int\left(u^{2}+2 u-u^{-1}-1\right) e^{u} \frac{du}{u - u^{-1}} = e^{u} \left(u^{2}+2 u-u^{-1}-1\right) \frac{1}{u - u^{-1}} \Biggr| - \int e^{u} \frac{d}{du} \left[\left(u^{2}+2 u-u^{-1}-1\right) \frac{1}{u - u^{-1}}\right] du$$
#
# Simplifying the expression, we get:
#
# $$e^{u} \left(u^{2}+2 u-u^{-1}-1\right) \frac{1}{u - u^{-1}} \Biggr| - \int e^{u} \frac{d}{du} \left[\left(u^{2}+2 u-u^{-1}-1\right) \frac{1}{u - u^{-1}}\right] du = g(x) e^{\left(e^{x}+e^{-x}\right)} + c$$
#
# Now, we can evaluate $g(0)$ by substituting $x = 0$:
#
# $$g(0) = \left[\left(e^{0}+e^{0}\right)^{2}+2 \left(e^{0}+e^{0}\right)-\left(e^{0}+e^{0}\right)^{-1}-1\right] \frac{1}{e^{0}+e^{0} - \left(e^{0}+e^{0}\right)^{-1}} = \boxed{2}$$
#
# Final Answer: 2
# <eot_id>
# Model's extracted answer: 2
# Is correct: True
# Explanation: The solution provided is mostly correct, but there are some minor errors and inconsistencies in the calculations. The approach is correct, and the final answer is obtained through a series of correct steps, but some of the intermediate expressions could be simplified or written more clearly.
# Number of correct solutions: 1
# --------------------------------------------------
#
# Problem 2:
# Q: If \(\int \sin ^{-1}\left(\sqrt{\frac{x}{1+x}}\right) d x=A(x) \tan ^{-1}(\sqrt{x})+B(x)+C\), where \(C\) is a constant of integration, then the ordered pair \((A(x)\), \(B(x)\) ) can be :
# Options: \((x+1,-\sqrt{x})\), \((x+1, \sqrt{x})\), \((x-1,-\sqrt{x})\), \((x-1, \sqrt{x})\)
# Correct answer: a
# Number of correct solutions: 0
# --------------------------------------------------
#
# Problem 3:
# Q: The integral \(\int \frac{2 x^{3}-1}{x^{4}+x} d x\) is equal to :
# Options: \(\frac{1}{2} \log _{e} \frac{\left|x^{3}+1\right|}{x^{2}}+C\), \(\frac{1}{2} \log _{e} \frac{\left(x^{3}+1\right)^{2}}{\left|x^{3}\right|}+C\), \(\quad \log _{e}\left|\frac{x^{3}+1}{x}\right|+C\), \(\log _{e} \frac{\left|x^{3}+1\right|}{x^{2}}+C\)
# Correct answer: c
#
# Solution 1 (Grade: 1.00):
# Model's solution:
# To solve this problem, we can start by rewriting the integral as:
#
# $$\int \frac{2x^3-1}{x^4+x}dx = \int \frac{2x^3-1}{x(x^3+1)}dx$$
#
# Now, we can use substitution to simplify the integral. Let's substitute $u = x^3 + 1$, which implies that $du/dx = 3x^2$. Then, we can rewrite the integral as:
#
# $$\int \frac{2x^3-1}{x(x^3+1)}dx = \int \frac{2x^3-1}{xu} \frac{du}{3x^2} = \frac{1}{3} \int \frac{2x-1/x}{u} du$$
#
# Now, we can integrate:
#
# $$\frac{1}{3} \int \frac{2x-1/x}{u} du = \frac{1}{3} \int \frac{2x}{u} du - \frac{1}{3} \int \frac{1}{xu} du$$
#
# The first integral can be evaluated as:
#
# $$\frac{1}{3} \int \frac{2x}{u} du = \frac{1}{3} \int \frac{2}{u} du = \frac{2}{3} \log|u| + C$$
#
# The second integral can be evaluated as:
#
# $$-\frac{1}{3} \int \frac{1}{xu} du = -\frac{1}{3} \int \frac{1}{x(x^3+1)} du = -\frac{1}{3} \int \frac{1}{x^4+x} du$$
#
# Now, we can substitute back $u = x^3 + 1$ to get:
#
# $$-\frac{1}{3} \int \frac{1}{x^4+x} du = -\frac{1}{3} \int \frac{1}{x(x^3+1)} dx = -\frac{1}{3} \log|x| + C$$
#
# Combining the two results, we get:
#
# $$\frac{1}{3} \int \frac{2x-1/x}{u} du = \frac{2}{3} \log|u| - \frac{1}{3} \log|x| + C$$
#
# Substituting back $u = x^3 + 1$, we get:
#
# $$\int \frac{2x^3-1}{x^4+x} dx = \frac{2}{3} \log|x^3+1| - \frac{1}{3} \log|x| + C$$
#
# Simplifying, we get:
#
# $$\int \frac{2x^3-1}{x^4+x} dx = \frac{1}{3} \log\left|\frac{x^3+1}{x}\right| + C$$
#
# Final Answer: C
# <eot_id>
# Model's extracted answer: c
# Is correct: True
# Explanation: The solution is perfectly correct, as it accurately evaluates the given integral using substitution and simplifies the result to obtain the final answer.
#
# Solution 2 (Grade: 1.00):
# Model's solution:
# To solve this integral, we can start by rewriting the expression as:
#
# $$\int \frac{2 x^{3}-1}{x^{4}+x} d x = \int \frac{2 x^{3}-1}{x(x^{3}+1)} d x$$
#
# Now, we can substitute $u = x^{3}+1$, which implies $du/dx = 3x^{2}$ and $dx = du/(3x^{2})$. The integral becomes:
#
# $$\int \frac{2 x^{3}-1}{x(x^{3}+1)} d x = \int \frac{2 x^{3}-1}{x(u)} \frac{du}{3x^{2}}$$
#
# Simplifying the expression, we get:
#
# $$\int \frac{2 x^{3}-1}{x(x^{3}+1)} d x = \frac{1}{3} \int \frac{2u-3}{u} du$$
#
# Now, we can integrate the expression:
#
# $$\frac{1}{3} \int \frac{2u-3}{u} du = \frac{1}{3} \left(2 \int \frac{u}{u} du - 3 \int \frac{1}{u} du\right)$$
#
# $$= \frac{1}{3} \left(2u - 3 \ln|u|\right) + C$$
#
# Substituting back $u = x^{3}+1$, we get:
#
# $$\int \frac{2 x^{3}-1}{x^{4}+x} d x = \frac{1}{3} \left(2(x^{3}+1) - 3 \ln|x^{3}+1|\right) + C$$
#
# Simplifying the expression, we get:
#
# $$\int \frac{2 x^{3}-1}{x^{4}+x} d x = \frac{2}{3} x^{3} + \frac{2}{3} - \ln|x^{3}+1| + C$$
#
# Final Answer: C
# <eot_id>
# Model's extracted answer: c
# Is correct: True
# Explanation: The solution is perfectly correct. It correctly evaluates the given integral using substitution and simplification, and arrives at the correct final answer.
# Number of correct solutions: 2
# --------------------------------------------------
#
# Problem 4:
# Q: Time taken by a 836 W heater to heat one litre of water from $10^{\circ} \mathrm{C}$ to $40^{\circ} \mathrm{C}$ is
#
# \\
# Options: a) 150 s\\, b) 100 s\\, c) 50 s\\, d) 200 s
# Correct answer: a
#
# Solution 1 (Grade: 1.00):
# Model's solution:
# To solve this problem, we need to use the formula for heat energy required to change the temperature of a substance:
#
# Heat energy (Q) = mass of substance (m) x specific heat capacity (c) x change in temperature (ΔT)
#
# Given:
# Power of the heater (P) = 836 W
# Initial temperature (T1) = 10°C = 283 K
# Final temperature (T2) = 40°C = 313 K
# Mass of water (m) = 1 litre = 1000 g (assuming density of water is 1 g/cm³)
# Specific heat capacity of water (c) = 4.184 J/g°C
#
# First, we need to find the heat energy required to change the temperature of 1 litre of water from 10°C to 40°C:
#
# ΔT = T2 - T1 = 313 K - 283 K = 30 K
#
# Q = m x c x ΔT
# = 1000 g x 4.184 J/g°C x 30°C
# = 125,520 J
#
# Now, we need to find the time taken by the heater to supply this amount of heat energy:
#
# Power (P) = 836 W = 836 J/s
#
# Time (t) = heat energy (Q) / power (P)
# = 125,520 J / 836 J/s
# = 150 s
#
# Final Answer: a) 150 s
# <eot_id>
# Model's extracted answer: a
# Is correct: True
# Explanation: The solution is perfectly correct. It correctly applies the formula for heat energy and time, and performs the necessary calculations to arrive at the correct answer.
#
# Solution 2 (Grade: 1.00):
# Model's solution:
# To solve this problem, we need to know that the specific heat capacity of water is 4200 J/kg°C.
#
# Let's first calculate the heat required to raise the temperature of 1 liter of water from 10°C to 40°C.
#
# Since 1 liter of water is equal to 1 kg, the heat required is:
#
# Q = m × c × ΔT
# = 1 kg × 4200 J/kg°C × (40°C - 10°C)
# = 1 kg × 4200 J/kg°C × 30°C
# = 126000 J
#
# Now, we need to find the time taken by the 836 W heater to provide this heat.
#
# We know that power (P) is equal to the heat (Q) divided by the time (t).
#
# So, we can write:
#
# 836 W = 126000 J / t
#
# To find the time, we can rearrange the equation as follows:
#
# t = 126000 J / 836 W
# = 150.6 s
#
# Rounding this value to the nearest whole number, we get:
#
# t = 151 s
#
# Since the options do not have 151 s, the closest option is 150 s.
#
# Final Answer: a) 150 s
# <eot_id>
# Model's extracted answer: a
# Is correct: True
# Explanation: The solution is perfectly correct. It correctly calculates the heat required and the time taken by the 836 W heater to provide that heat. The calculations are accurate, and the final answer is correct.
#
# Solution 3 (Grade: 1.00):
# Model's solution:
# To solve this problem, we need to use the concept of heat transfer and specific heat capacity of water.
#
# Let's break down the problem step by step:
#
# 1. First, we need to find the amount of heat required to raise the temperature of 1 liter of water from 10°C to 40°C. The specific heat capacity of water is approximately 4.184 J/g°C.
#
# Let's convert the temperature difference from Celsius to Kelvin: ΔT = 40°C - 10°C = 30°C = 30 K
#
# The mass of 1 liter of water is 1000 g. So, the amount of heat required is:
#
# Q = m × c × ΔT
# = 1000 g × 4.184 J/g°C × 30 K
# = 125,520 J
#
# 2. Now, we need to find the time taken to supply this amount of heat. The heater has a power rating of 836 W.
#
# The time taken to supply the heat can be found using the formula:
#
# t = Q / P
# where Q is the amount of heat required and P is the power rating of the heater.
#
# t = 125,520 J / 836 W
# = 150 s
#
# Final Answer: a) 150 s
# <eot_id>
# Model's extracted answer: a
# Is correct: True
# Explanation: The solution is perfectly correct. It correctly calculates the amount of heat required to raise the temperature of 1 liter of water from 10°C to 40°C using the specific heat capacity of water and then uses the power rating of the heater to find the time taken to supply that amount of heat.
# Number of correct solutions: 3
# --------------------------------------------------
#
# Problem 5:
# Q: Let \(\alpha \in(0, \pi / 2)\) be fixed. If the integral \(\int \frac{\tan x+\tan \alpha}{\tan x-\tan \alpha} d x=\mathrm{A}(x) \cos 2 \alpha+\mathrm{B}(x) \sin 2 \alpha+\mathrm{C}\), where \(\mathrm{C}\) is a constant of integration, then the functions \(\mathrm{A}(x)\) and \(\mathrm{B}(x)\) are respectively :
# Options: \(x+\alpha\) and \(\log _{e}|\sin (x+\alpha)|\), \(x-\alpha\) and \(\log _{e} \mid \sin (x-\alpha)\), \(x-\alpha\) and \(\log _{e}|\cos (x-\alpha)|\), \(x+\alpha\) and \(\log _{e}|\sin (x-\alpha)|\)
# Correct answer: b
#
# Solution 1 (Grade: 1.00):
# Model's solution:
# Here's the step-by-step solution to the problem:
#
# Let's start by rewriting the given integral:
#
# $$\int \frac{\tan x+\tan \alpha}{\tan x-\tan \alpha} d x$$
#
# Using the tangent sum and difference formulas, we can rewrite the integrand as:
#
# $$\frac{\tan x+\tan \alpha}{\tan x-\tan \alpha} = \frac{\frac{\sin x}{\cos x}+\frac{\sin \alpha}{\cos \alpha}}{\frac{\sin x}{\cos x}-\frac{\sin \alpha}{\cos \alpha}}$$
#
# $$= \frac{\sin x \cos \alpha+\sin \alpha \cos x}{\sin x \cos \alpha-\sin \alpha \cos x}$$
#
# $$= \frac{\sin(x+\alpha)}{\sin(x-\alpha)}$$
#
# Now, we can rewrite the integral as:
#
# $$\int \frac{\sin(x+\alpha)}{\sin(x-\alpha)} d x$$
#
# To evaluate this integral, we can use the substitution:
#
# $$u = x-\alpha \Rightarrow d u = d x$$
#
# Substituting this into the integral, we get:
#
# $$\int \frac{\sin(u+2\alpha)}{\sin u} d u$$
#
# Using the trigonometric identity:
#
# $$\sin(u+2\alpha) = \sin u \cos 2\alpha + \cos u \sin 2\alpha$$
#
# We can rewrite the integrand as:
#
# $$\frac{\sin(u+2\alpha)}{\sin u} = \cos 2\alpha + \cot u \sin 2\alpha$$
#
# Now, we can evaluate the integral:
#
# $$\int (\cos 2\alpha + \cot u \sin 2\alpha) d u$$
#
# $$= \cos 2\alpha \int d u + \sin 2\alpha \int \cot u d u$$
#
# $$= \cos 2\alpha u + \sin 2\alpha \log |\sin u| + C$$
#
# Substituting back $u = x-\alpha$, we get:
#
# $$\int \frac{\tan x+\tan \alpha}{\tan x-\tan \alpha} d x = \cos 2\alpha (x-\alpha) + \sin 2\alpha \log |\sin(x-\alpha)| + C$$
#
# Comparing this with the given form:
#
# $$A(x) \cos 2\alpha + B(x) \sin 2\alpha + C$$
#
# We can see that:
#
# $$A(x) = x-\alpha \quad \text{and} \quad B(x) = \log_e |\sin(x-\alpha)|$$
#
# Final Answer: B
# <eot_id>
# Model's extracted answer: b
# Is correct: True
# Explanation: The solution provided is correct and well-explained, with each step justified and the final answer matching the expected form.
#
# Solution 2 (Grade: 1.00):
# Model's solution:
# Let's solve the problem step by step.
#
# We are given the integral:
#
# $$\int \frac{\tan x+\tan \alpha}{\tan x-\tan \alpha} d x=\mathrm{A}(x) \cos 2 \alpha+\mathrm{B}(x) \sin 2 \alpha+\mathrm{C}$$
#
# where $\mathrm{C}$ is a constant of integration.
#
# To evaluate this integral, we can use the substitution:
#
# $$\tan x=t$$
#
# Then, we have:
#
# $$dx=\frac{dt}{1+t^2}$$
#
# Substituting this into the integral, we get:
#
# $$\int \frac{\frac{t+\tan \alpha}{1+t^2}}{\frac{t-\tan \alpha}{1+t^2}} \frac{dt}{1+t^2}=\int \frac{t+\tan \alpha}{t-\tan \alpha} \frac{dt}{1+t^2}$$
#
# Now, we can simplify the integrand:
#
# $$\int \frac{t+\tan \alpha}{t-\tan \alpha} \frac{dt}{1+t^2}=\int \frac{1+\frac{\tan \alpha}{t}}{1-\frac{\tan \alpha}{t}} \frac{dt}{1+t^2}$$
#
# Using the substitution:
#
# $$u=\frac{\tan \alpha}{t}$$
#
# We have:
#
# $$du=-\frac{\tan \alpha}{t^2} dt$$
#
# Substituting this into the integral, we get:
#
# $$\int \frac{1+u}{1-u} \frac{-t^2}{\tan \alpha} du=\int \frac{t^2}{\tan \alpha} \frac{1+u}{1-u} du$$
#
# Now, we can integrate:
#
# $$\int \frac{t^2}{\tan \alpha} \frac{1+u}{1-u} du=\frac{t^2}{\tan \alpha} \log_e|1-u|+C$$
#
# Substituting back $u=\frac{\tan \alpha}{t}$, we get:
#
# $$\frac{t^2}{\tan \alpha} \log_e|1-\frac{\tan \alpha}{t}|+C$$
#
# Substituting back $t=\tan x$, we get:
#
# $$\tan^2 x \log_e|\frac{\tan x-\tan \alpha}{\tan x}|+C$$
#
# Simplifying, we get:
#
# $$\tan^2 x \log_e|\sin(x-\alpha)|+C$$
#
# Comparing this with the given expression, we can see that:
#
# $$A(x)=x, \quad B(x)=\log_e|\sin(x-\alpha)|$$
#
# Therefore, the correct answer is:
#
# Final Answer: B. $x-\alpha$ and $\log_e|\sin(x-\alpha)|$.
# <eot_id>
# Model's extracted answer: b
# Is correct: True
# Explanation: The solution is correct and well-explained, with each step clearly justified. The final answer is also correctly identified as B.
# Number of correct solutions: 2
# --------------------------------------------------
#
# Overall Accuracy: 80.00%

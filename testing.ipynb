# %%
# Out:
# ERROR: Can't invoke 'meta.llama3-70b-instruct-v1:0'. Reason: An error occurred (InvalidSignatureException) when calling the InvokeModel operation: The request signature we calculated does not match the signature you provided. Check your AWS Secret Access Key and signing method. Consult the service documentation for details.

# %%
pip install --upgrade boto3
# Out:
# Requirement already satisfied: boto3 in c:\users\shivam dave\miniconda3\lib\site-packages (1.35.0)
# Collecting boto3
#   Downloading boto3-1.35.10-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<1.36.0,>=1.35.10 (from boto3)
#   Downloading botocore-1.35.10-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\shivam dave\miniconda3\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\shivam dave\miniconda3\lib\site-packages (from boto3) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\shivam dave\miniconda3\lib\site-packages (from botocore<1.36.0,>=1.35.10->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\shivam dave\miniconda3\lib\site-packages (from botocore<1.36.0,>=1.35.10->boto3) (1.26.18)
# Requirement already satisfied: six>=1.5 in c:\users\shivam dave\miniconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.10->boto3) (1.16.0)
# Downloading boto3-1.35.10-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/139.2 kB 660.6 kB/s eta 0:00:01
#    ----------------- --------------------- 61.4/139.2 kB 656.4 kB/s eta 0:00:01
#    ------------------------- ------------- 92.2/139.2 kB 655.4 kB/s eta 0:00:01
#    ------------------------------------ - 133.1/139.2 kB 653.6 kB/s eta 0:00:01
#    -------------------------------------- 139.2/139.2 kB 548.6 kB/s eta 0:00:00
# Downloading botocore-1.35.10-py3-none-any.whl (12.5 MB)
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.5 MB 660.6 kB/s eta 0:00:19
#    ---------------------------------------- 0.1/12.5 MB 812.7 kB/s eta 0:00:16
#    ---------------------------------------- 0.1/12.5 MB 751.6 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/12.5 MB 722.1 kB/s eta 0:00:18
#     --------------------------------------- 0.2/12.5 MB 756.6 kB/s eta 0:00:17
#     --------------------------------------- 0.2/12.5 MB 737.3 kB/s eta 0:00:17
#     --------------------------------------- 0.2/12.5 MB 724.0 kB/s eta 0:00:17
#     --------------------------------------- 0.3/12.5 MB 714.4 kB/s eta 0:00:18
#     --------------------------------------- 0.3/12.5 MB 707.1 kB/s eta 0:00:18
#    - -------------------------------------- 0.3/12.5 MB 752.2 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/12.5 MB 742.3 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/12.5 MB 734.3 kB/s eta 0:00:17
#    - -------------------------------------- 0.4/12.5 MB 727.5 kB/s eta 0:00:17
#    - -------------------------------------- 0.5/12.5 MB 741.3 kB/s eta 0:00:17
#    - -------------------------------------- 0.5/12.5 MB 750.8 kB/s eta 0:00:16
#    - -------------------------------------- 0.5/12.5 MB 726.3 kB/s eta 0:00:17
#    - -------------------------------------- 0.6/12.5 MB 750.9 kB/s eta 0:00:16
#    - -------------------------------------- 0.6/12.5 MB 730.5 kB/s eta 0:00:17
#    -- ------------------------------------- 0.6/12.5 MB 740.1 kB/s eta 0:00:17
#    -- ------------------------------------- 0.7/12.5 MB 735.5 kB/s eta 0:00:17
#    -- ------------------------------------- 0.7/12.5 MB 731.4 kB/s eta 0:00:17
#    -- ------------------------------------- 0.7/12.5 MB 738.9 kB/s eta 0:00:16
#    -- ------------------------------------- 0.8/12.5 MB 745.8 kB/s eta 0:00:16
#    -- ------------------------------------- 0.8/12.5 MB 731.4 kB/s eta 0:00:16
#    -- ------------------------------------- 0.8/12.5 MB 738.7 kB/s eta 0:00:16
#    -- ------------------------------------- 0.9/12.5 MB 735.2 kB/s eta 0:00:16
#    -- ------------------------------------- 0.9/12.5 MB 740.5 kB/s eta 0:00:16
#    -- ------------------------------------- 0.9/12.5 MB 737.3 kB/s eta 0:00:16
#    --- ------------------------------------ 1.0/12.5 MB 734.2 kB/s eta 0:00:16
#    --- ------------------------------------ 1.0/12.5 MB 731.4 kB/s eta 0:00:16
#    --- ------------------------------------ 1.0/12.5 MB 737.3 kB/s eta 0:00:16
#    --- ------------------------------------ 1.1/12.5 MB 741.7 kB/s eta 0:00:16
#    --- ------------------------------------ 1.1/12.5 MB 738.9 kB/s eta 0:00:16
#    --- ------------------------------------ 1.1/12.5 MB 736.3 kB/s eta 0:00:16
#    --- ------------------------------------ 1.2/12.5 MB 733.3 kB/s eta 0:00:16
#    --- ------------------------------------ 1.2/12.5 MB 738.8 kB/s eta 0:00:16
#    --- ------------------------------------ 1.2/12.5 MB 736.3 kB/s eta 0:00:16
#    --- ------------------------------------ 1.2/12.5 MB 734.0 kB/s eta 0:00:16
#    ---- ----------------------------------- 1.3
kB/s eta 0:00:03
#    ---------------------------------- ----- 10.8/12.5 MB 693.5 kB/s eta 0:00:03
#    ---------------------------------- ----- 10.9/12.5 MB 693.5 kB/s eta 0:00:03
#    ---------------------------------- ----- 10.9/12.5 MB 695.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 10.9/12.5 MB 694.2 kB/s eta 0:00:03
#    ----------------------------------- ---- 11.0/12.5 MB 693.5 kB/s eta 0:00:03
#    ----------------------------------- ---- 11.0/12.5 MB 692.8 kB/s eta 0:00:03
#    ----------------------------------- ---- 11.0/12.5 MB 694.2 kB/s eta 0:00:03
#    ----------------------------------- ---- 11.1/12.5 MB 694.3 kB/s eta 0:00:03
#    ----------------------------------- ---- 11.1/12.5 MB 695.0 kB/s eta 0:00:03
#    ----------------------------------- ---- 11.1/12.5 MB 693.5 kB/s eta 0:00:03
#    ----------------------------------- ---- 11.2/12.5 MB 693.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.2/12.5 MB 693.5 kB/s eta 0:00:02
#    ----------------------------------- ---- 11.2/12.5 MB 694.2 kB/s eta 0:00:02
#    ------------------------------------ --- 11.3/12.5 MB 694.2 kB/s eta 0:00:02
#    ------------------------------------ --- 11.3/12.5 MB 692.8 kB/s eta 0:00:02
#    ------------------------------------ --- 11.3/12.5 MB 693.5 kB/s eta 0:00:02
#    ------------------------------------ --- 11.4/12.5 MB 693.5 kB/s eta 0:00:02
#    ------------------------------------ --- 11.4/12.5 MB 694.2 kB/s eta 0:00:02
#    ------------------------------------ --- 11.4/12.5 MB 694.3 kB/s eta 0:00:02
#    ------------------------------------ --- 11.5/12.5 MB 694.2 kB/s eta 0:00:02
#    ------------------------------------ --- 11.5/12.5 MB 693.5 kB/s eta 0:00:02
#    ------------------------------------ --- 11.5/12.5 MB 694.2 kB/s eta 0:00:02
#    ------------------------------------- -- 11.6/12.5 MB 693.5 kB/s eta 0:00:02
#    ------------------------------------- -- 11.6/12.5 MB 701.0 kB/s eta 0:00:02
#    ------------------------------------- -- 11.6/12.5 MB 699.5 kB/s eta 0:00:02
#    ------------------------------------- -- 11.7/12.5 MB 697.2 kB/s eta 0:00:02
#    ------------------------------------- -- 11.7/12.5 MB 695.0 kB/s eta 0:00:02
#    ------------------------------------- -- 11.7/12.5 MB 695.8 kB/s eta 0:00:02
#    ------------------------------------- -- 11.8/12.5 MB 695.8 kB/s eta 0:00:02
#    ------------------------------------- -- 11.8/12.5 MB 695.0 kB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.5 MB 695.0 kB/s eta 0:00:01
#    ------------------------------------- -- 11.9/12.5 MB 695.8 kB/s eta 0:00:01
#    -------------------------------------- - 11.9/12.5 MB 695.8 kB/s eta 0:00:01
#    -------------------------------------- - 12.0/12.5 MB 695.7 kB/s eta 0:00:01
#    -------------------------------------- - 12.0/12.5 MB 695.8 kB/s eta 0:00:01
#    -------------------------------------- - 12.0/12.5 MB 695.8 kB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.5 MB 695.8 kB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.5 MB 695.8 kB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.5 MB 695.8 kB/s eta 0:00:01
#    -------------------------------------- - 12.1/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.2/12.5 MB 695.0 kB/s eta 0:00:01
#    ---------------------------------------  12.2/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.3/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.4/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.4/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.4/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.5/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------  12.5/12.5 MB 695.8 kB/s eta 0:00:01
#    ---------------------------------------- 12.5/12.5 MB 693.9 kB/s eta 0:00:00
# Installing collected packages: botocore, boto3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.35.0
#     Uninstalling botocore-1.35.0:
#       Successfully uninstalled botocore-1.35.0
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.35.0
#     Uninstalling boto3-1.35.0:
#       Successfully uninstalled boto3-1.35.0
# Successfully installed boto3-1.35.10 botocore-1.35.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import boto3
from botocore.exceptions import ClientError
import re
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

class BedrockClient:
    def __init__(self, region_name, model_id):
        self.client = boto3.client('bedrock-runtime', region_name=region_name)
        self.model_id = model_id
        self.dataset = self.load_dataset()[:5]  # Load only first 5 questions

    def load_dataset(self):
        with open('RepresentativeDataset.json', 'r') as f:
            return json.load(f)

    def create_prompt(self, question, options):
        prompt = f"Solve the following mathematical problem:\n\nQuestion: {question}\n"
        prompt += f"Options: {', '.join(options)}\n\n"
        prompt += "Provide your solution and clearly state your final answer at the end, prefixed with the option choice as an alphabet for eg ('a' if 1 ) as 'Final Answer: '."
        
        return f"""<begin_of_text>
<start_header_id>user<end_header_id>
{prompt}
<eot_id>
<start_header_id>assistant<end_header_id>
"""

    def invoke_model(self, question, options, max_tokens=1024, temperature=0.7):
        formatted_prompt = self.create_prompt(question, options)
        
        request_body = {
            "prompt": formatted_prompt,
            "max_gen_len": max_tokens,
            "temperature": temperature,
        }
        
        try:
            response = self.client.invoke_model(
                body=json.dumps(request_body),
                contentType='application/json',
                modelId=self.model_id
            )
            response_body = json.loads(response['body'].read().decode('utf-8'))
            return response_body.get('generation', '')
        except ClientError as e:
            print(f"ERROR: Can't invoke '{self.model_id}'. Reason: {e}")
            return None

    def extract_model_answer(self, model_solution):
        match = re.search(r"Final Answer:\s*(\w+)", model_solution, re.IGNORECASE)
        if match:
            return match.group(1).lower()
        return None

    def process_questions(self):
        results = []
        correct_count = 0
        for problem in self.dataset:
            result = self.invoke_model(problem['question'], problem['options'])
            model_answer = self.extract_model_answer(result)
            is_correct = model_answer == problem['answer'].lower() if model_answer else False
            if is_correct:
                correct_count += 1
            
            results.append({
                'question': problem['question'],
                'model_solution': result,
                'model_answer': model_answer,
                'correct_solution': problem['solution'],
                'correct_answer': problem['answer'],
                'is_correct': is_correct
            })
        
        accuracy = correct_count / len(self.dataset) if self.dataset else 0
        return results, accuracy

def main():
    region_name = os.environ.get('AWS_REGION', 'us-east-1')
    model_id = os.environ.get('BEDROCK_MODEL_ID', 'meta.llama2-70b-chat-v1')
    
    client = BedrockClient(region_name, model_id)
    results, accuracy = client.process_questions()
    
    # Print results
    for i, result in enumerate(results, 1):
        print(f"\nQuestion {i}:")
        print(f"Q: {result['question']}")
        print(f"Model's solution:\n{result['model_solution']}")
        print(f"Model's extracted answer: {result['model_answer']}")
        print(f"Correct solution: {result['correct_solution']}")
        print(f"Correct answer: {result['correct_answer']}")
        print(f"Is correct: {result['is_correct']}")
        print("-" * 50)

    print(f"\nOverall Accuracy: {accuracy:.2%}")

if __name__ == "__main__":
    main()
# Out:
# Question 1:
# Q: If \(\int\left(e^{2 x}+2 e^{x}-e^{-x}-1\right) e^{\left(e^{x}+e^{-x}\right)} d x=g(x) e^{\left(e^{x}+e^{-x}\right)}+c\), where \(c\) is a constant of integeration, then \(g(0)\) is equal to:
# Model's solution:
# Final Answer: a
#
# The given problem is:
#
# g(x) = e^(x + e^(-x)) + c
#
# We need to find g(0).
#
# g(0) = e^(0 + e^(-0)) + c
# = e^(e^(-0)) + c
# = e^(1) + c
#
# So, g(0) is equal to e + c.
#
# Now, the options are:
#
# a) e
# b) e^2
# c) 1
# d) 2
#
# The correct answer is 'a' e.
# Model's extracted answer: a
# Correct solution: }
#   \item (d) \(\int\left(e^{2 x}+2 e^{x}-e^{-x}-1\right) \cdot e^{\left(e^{x}+e^{-x}\right)} d x\)
#
#
# \(I=\int\left(e^{2 x}+e^{x}-1\right) \cdot e^{\left(e^{x}+e^{-x}\right)} d x+\int\left(e^{x}-e^{-x}\right) e^{\left(e^{x}+e^{-x}\right)} d x\)
#
# \(=\int e^{x}\left(e^{x}+1-e^{-x}\right) \cdot e^{\left(e^{x}+e^{-x}\right)} d x+e^{\left(e^{x}+e^{-x}\right)}\)
#
# \(=\int\left(e^{x}-e^{-x}+1\right) e^{\left(e^{x}+e^{-x}+x\right)} d x+e^{\left(e^{x}+e^{-x}\right)}\)
#
# Let \(e^{x}+e^{-x}+x=t \Rightarrow\left(e^{x}+e^{-x}+1\right) d x=d t\)
#
# \(=\int e^{t} d t+e^{\left(e^{x}+e^{-x}\right)}=e^{t}+e^{\left(e^{x}+e^{-x}\right)}+C\)
#
# \(=e^{\left(e^{x}+e^{-x}+x\right)}+e^{\left(e^{x}+e^{-x}\right)}+C\)
#
# \(=\left(e^{x}+1\right) \cdot e^{\left(e^{x}+e^{-x}\right)}+C\)
#
# So, \(g(x)=1+e^{x}\) and \(g(0)=2\)
# Correct answer: d
# Is correct: False
# --------------------------------------------------
#
# Question 2:
# Q: If \(\int \sin ^{-1}\left(\sqrt{\frac{x}{1+x}}\right) d x=A(x) \tan ^{-1}(\sqrt{x})+B(x)+C\), where \(C\) is a constant of integration, then the ordered pair \((A(x)\), \(B(x)\) ) can be :
# Model's solution:
# To solve this problem, we can start by integrating the given function.
#
# Let's assume that $\int \sin ^{-1}\left(\sqrt{\frac{x}{1+x}}\right) d x = I$.
#
# Using substitution, let $\sqrt{\frac{x}{1+x}} = t$. Then, $\frac{dx}{dt} = \frac{2t(1+t^2)}{1-t^2}$.
#
# Now, we can rewrite the integral as:
#
# $I = \int \sin ^{-1}(t) \cdot \frac{2t(1+t^2)}{1-t^2} dt$
#
# Using integration by parts, we get:
#
# $I = \tan ^{-1}(t) \cdot \frac{2t^2}{1-t^2} - \int \frac{2t^2}{(1-t^2)^2} dt + C$
#
# Now, we can simplify the integral:
#
# $I = \tan ^{-1}(t) \cdot \frac{2t^2}{1-t^2} - \frac{1}{1-t^2} + C$
#
# Substituting back $t = \sqrt{\frac{x}{1+x}}$, we get:
#
# $I = \tan ^{-1}(\sqrt{x}) \cdot (x+1) - \sqrt{x} + C$
#
# Comparing this with the given equation, we can see that $A(x) = x+1$ and $B(x) = -\sqrt{x}$. Therefore, the correct answer is:
#
# Final Answer: (a) $(x+1,-\sqrt{x})$
# <eot_id>
# Model's extracted answer: None
# Correct solution: }
#   \item (a) \(I=\int \sin ^{-1}\left(\frac{\sqrt{x}}{\sqrt{1+x}}\right) d x=\int \tan ^{-1} \sqrt{x} \cdot 1 d x\)\\
# \(=x \tan ^{-1} \sqrt{x}-\int \frac{1}{1+x} \cdot \frac{1}{2 \sqrt{x}} \cdot x d x+C\)\\
# \(=x \tan ^{-1} \sqrt{x}-\frac{1}{2} \int \frac{t \cdot 2 t d t}{1+t^{2}}+C\)
#
#
# (Put \(x=t^{2} \Rightarrow d x=2 t d t\) )
#
# \(=x \tan ^{-1} \sqrt{x}-\int \frac{t^{2}}{1+t^{2}} d t+C\)
#
# \(=x \tan ^{-1} \sqrt{x}-t+\tan ^{-1} t+C\)
#
# \(=x \tan ^{-1} \sqrt{x}-\sqrt{x}+\tan ^{-1} \sqrt{x}+C\)
#
# \(=(x+1) \tan ^{-1} \sqrt{x}-\sqrt{x}+C\)
#
# \(\Rightarrow A(x)=x+1 \Rightarrow B(x)=-\sqrt{x}\)
# Correct answer: a
# Is correct: False
# --------------------------------------------------
#
# Question 3:
# Q: The integral \(\int \frac{2 x^{3}-1}{x^{4}+x} d x\) is equal to :
# Model's solution:
# The integral can be solved using substitution and partial fraction decomposition.
#
# Let $u = x^3 + 1$, then $du/dx = 3x^2$, and $dx = du/(3x^2)$.
#
# Substituting into the original integral, we get:
#
# $$\int \frac{2x^3 - 1}{x^4 + x} dx = \int \frac{2u - 3}{u} \frac{du}{3x^2}$$
#
# Now, we can use partial fraction decomposition:
#
# $$\frac{2u - 3}{u} = \frac{A}{u} + \frac{B}{u + 1}$$
#
# Multiplying both sides by $u(u + 1)$, we get:
#
# $$2u - 3 = A(u + 1) + Bu$$
#
# Equating coefficients, we get $A = 3$ and $B = -1$.
#
# Now, we can rewrite the integral as:
#
# $$\int \frac{2x^3 - 1}{x^4 + x} dx = \int \frac{3}{u} \frac{du}{3x^2} - \int \frac{1}{u + 1} \frac{du}{3x^2}$$
#
# Integrating, we get:
#
# $$\int \frac{2x^3 - 1}{x^4 + x} dx = \frac{1}{x^2} \log_e |u| - \frac{1}{3x^2} \log_e |u + 1| + C$$
#
# Substituting back $u = x^3 + 1$, we get:
#
# $$\int \frac{2x^3 - 1}{x^4 + x} dx = \log_e \frac{|x^3 + 1|}{x^2} + C$$
#
# Final Answer: d.
# <eot_id>
# Model's extracted answer: d
# Correct solution: }
#   \item (c) Given integral, \(I=\int \frac{\left(2 x^{3}-1\right) d x}{x^{4}+x}=\int \frac{\left(2 x-x^{-2}\right) d x}{x^{2}+x^{-1}}\)
#
#
# Put \(x^{2}+x^{-1}=u \Rightarrow\left(2 x-x^{-2}\right) d x=d u\)
#
# \(\Rightarrow I=\int \frac{d u}{u}=\log |u|+c=\log \left|x^{2}+x^{-1}\right|+c\)
#
# \(=\log \left|\frac{x^{3}+1}{x}\right|+c\)
# Correct answer: c
# Is correct: False
# --------------------------------------------------
#
# Question 4:
# Q: Time taken by a 836 W heater to heat one litre of water from $10^{\circ} \mathrm{C}$ to $40^{\circ} \mathrm{C}$ is
#
# \\
# Model's solution:
# To solve this problem, we need to use the formula for heat energy transferred:
#
# Q = mcΔT
#
# where Q is the heat energy, m is the mass of water, c is the specific heat capacity of water, and ΔT is the change in temperature.
#
# First, we need to find the mass of 1 liter of water. The density of water is approximately 1 g/cm³, so the mass of 1 liter of water is:
#
# m = 1000 g = 1 kg
#
# The specific heat capacity of water is approximately 4.184 J/g°C. The change in temperature is:
#
# ΔT = 40°C - 10°C = 30°C
#
# Now, we can plug in the values to find the heat energy required:
#
# Q = mcΔT
# = 1 kg x 4.184 J/g°C x 30°C
# = 1255.2 J
#
# The heater provides 836 W of power. To find the time taken to heat the water, we can use the formula:
#
# Power = Energy / Time
#
# Rearranging to solve for time, we get:
#
# Time = Energy / Power
# = 1255.2 J / 836 W
# = 150 s
#
# Final Answer: a) 150 s
# <eot_id>
# Model's extracted answer: a
# Correct solution: Heat supplied in time $t$ for heating 1L water from $10^{\circ} \mathrm{C}$ to $40^{\circ} \mathrm{C}$   $\Delta Q=m C_{p} \times \Delta T$  $=1 \times 4180 \times(40-10)=4180 \times 30$  But $\Delta Q=P \times t=836 \times t$  $\Rightarrow t=\frac{4180 \times 30}{836}=150 \mathrm{~s}$  \begin{enumerate}
# Correct answer: a
# Is correct: True
# --------------------------------------------------
#
# Question 5:
# Q: Let \(\alpha \in(0, \pi / 2)\) be fixed. If the integral \(\int \frac{\tan x+\tan \alpha}{\tan x-\tan \alpha} d x=\mathrm{A}(x) \cos 2 \alpha+\mathrm{B}(x) \sin 2 \alpha+\mathrm{C}\), where \(\mathrm{C}\) is a constant of integration, then the functions \(\mathrm{A}(x)\) and \(\mathrm{B}(x)\) are respectively :
# Model's solution:
# Let's evaluate the given integral:
#
# $$\int \frac{\tan x+\tan \alpha}{\tan x-\tan \alpha} d x$$
#
# We can rewrite the integral as:
#
# $$\int \frac{\frac{\sin x}{\cos x}+\frac{\sin \alpha}{\cos \alpha}}{\frac{\sin x}{\cos x}-\frac{\sin \alpha}{\cos \alpha}} d x$$
#
# Now, we can substitute $u = \tan x$, which implies $du = \sec^2 x dx$. Then, we have:
#
# $$\int \frac{u+\tan \alpha}{u-\tan \alpha} \frac{du}{\sec^2 x}$$
#
# Simplifying the expression, we get:
#
# $$\int \frac{u+\tan \alpha}{u-\tan \alpha} \frac{1}{1+u^2} du$$
#
# Now, we can substitute $v = u - \tan \alpha$, which implies $dv = du$. Then, we have:
#
# $$\int \frac{v+\tan \alpha+\tan \alpha}{v} \frac{1}{1+(v+\tan \alpha)^2} dv$$
#
# Simplifying the expression, we get:
#
# $$\int \frac{1}{v} + \frac{2\tan \alpha}{v^2+2v\tan \alpha+1+\tan^2 \alpha} dv$$
#
# Now, we can integrate the expression term by term:
#
# $$\log |v| - \frac{2\tan \alpha}{\sqrt{1+\tan^2 \alpha}} \arctan \left(\frac{v+\tan \alpha}{\sqrt{1+\tan^2 \alpha}}\right) + C$$
#
# Substituting back $v = u - \tan \alpha$ and $u = \tan x$, we get:
#
# $$\log |\tan x-\tan \alpha| - \frac{2\tan \alpha}{\sqrt{1+\tan^2 \alpha}} \arctan \left(\frac{\tan x}{\sqrt{1+\tan^2 \alpha}}\right) + C$$
#
# Using the properties of logarithms and arctangents, we can rewrite the expression as:
#
# $$\log |\sin(x-\alpha)| - \log |\cos \alpha| + \frac{2\tan \alpha}{\sqrt{1+\tan^2 \alpha}} \arctan \left(\tan \left(\frac{x-\alpha}{2}\right)\right) + C$$
#
# Simplifying the expression, we get:
#
# $$\log |\sin(x-\alpha)| + x \cos 2\alpha - \log |\cos \alpha| + C$$
#
# Comparing this with the given expression:
#
# $$\mathrm{A}(x) \cos 2\alpha + \mathrm{B}(x) \sin 2\alpha + \mathrm{C}$$
#
# We can conclude that $\mathrm{A}(x) = x-\alpha$ and $\mathrm{B}(x) = \log_e |\sin(x-\alpha)|$.
#
# Final Answer: b
# Model's extracted answer: b
# Correct solution: }
#   \item (b) Given integral
#
#
# \(\int \frac{\tan x+\tan \alpha}{\tan x-\tan \alpha} d x=\int \frac{\sin (x+\alpha)}{\sin (x-\alpha)} d x\)
#
# Let \(x-\alpha=t \Rightarrow d x=d t\)
#
# \(=\int \frac{\sin (t+2 \alpha)}{\sin t} d t=\int[\cos 2 \alpha+\sin 2 \alpha \cdot \cot t] d t\)
#
# \(=\cos 2 \alpha \cdot t+\sin 2 \alpha \cdot \log |\sin t|+c\)
#
# \(=(x-\alpha) \cdot \cos 2 \alpha+\sin 2 \alpha \cdot \log |\sin (x-\alpha)|+c\)
# Correct answer: b
# Is correct: True
# --------------------------------------------------
#
# Overall Accuracy: 40.00%
